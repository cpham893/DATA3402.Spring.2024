# %%
import math

# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, max, x=0):
        self.m=max
        self.x=x

    def increment(self):
        if self.x<self.m:
            self.x+=1
            print("current count: ",self.x)
        else:
            print("error: exceeds max number")

    def reset(self):
        self.x=0

# %%
count=counter(3)

count.increment()
count.increment()
count.increment()
count.increment()

count.reset()
count.increment()
# Out:
# current count:  1
# current count:  2
# current count:  3
# error: exceeds max number
# current count:  1

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter2:
    def __init__(self, max, x=0):
        self.__m=max
        self.__x=x

    def increment(self):
        if self.__x<self.__m:
            self.__x+=1
            print("count: ",self.__x)
        else:
            print("error: exceeds max number")

    def reset(self):
        self.__x=0
        print(self.__x)

    def get_count(self):
        print("current count: ",self.__x)

    def get_max_count(self):
        print("max count: ",self.__m)

    def is_at_max(self):
        print("is it at max count: ",self.__x==self.__m)

# %%
counter=counter2(3)

counter.increment()
counter.increment()
counter.get_count()
counter.get_max_count()
counter.is_at_max()
counter.increment()
counter.increment()
counter.is_at_max()

counter.reset()
counter.get_count()
# Out:
# count:  1
# count:  2
# current count:  2
# max count:  3
# is it at max count:  False
# count:  3
# error: exceeds max number
# is it at max count:  True
# 0
# current count:  0

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self, length, width, x, y):
        self.__l=length
        self.__w=width
        self.__coor=(x,y)

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(self.__l*2)+(self.__w*2)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def get_coordinates(self):
        return self.__coor

# %%
rec=rectangle(5,4,1,1)

rec.area()
rec.perimeter()
print("rectangle\n")
print("area: ",rec.get_area())
print("perimeter: ",rec.get_perimeter())
print("coordinates: ",rec.get_coordinates())
# Out:
# rectangle
#
# area:  20
# perimeter:  18
# coordinates:  (1, 1)

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self, radius, x, y):
        self.__r=radius
        self.__coor=(x,y)

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def get_coordinates(self):
        return self.__coor

# %%
cir=circle(5,1,0)

cir.area()
cir.perimeter()
print("circle\n")
print("area: ",cir.get_area())
print("perimeter: ",cir.get_perimeter())
print("coordinates: ",cir.get_coordinates())
# Out:
# circle
#
# area:  78.53981633974483
# perimeter:  31.41592653589793
# coordinates:  (1, 0)

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement those classes to inherit from the base class and overload the functions accordingly.

# %%
class shapes:
    def __init__(self, x, y):
        self.__coor=(x,y)

    def get_coordinates(self):
        return self.__coor

class rectangle(shapes):
    def __init__(self, length, width, x, y, init_parent=True):
        if init_parent:
            super(rectangle,self).__init__(x, y)
        self.__l=length
        self.__w=width

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(2*self.__l)+(2*self.__w)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

class circle(shapes):
    def __init__(self, radius, x, y, init_parent=True):
        if init_parent:
            super(circle,self).__init__(x, y)
        self.__r=radius

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

# %%
rec=rectangle(4,5,0,0)

rec.area()
rec.perimeter()
print("area: ",rec.get_area())
print("perimeter: ",rec.get_perimeter())
print("coordinates: ",rec.get_coordinates())
# Out:
# area:  20
# perimeter:  18
# coordinates:  (0, 0)

# %%
cir=circle(5,2,4)

cir.area()
cir.perimeter()
print("area: ",cir.get_area())
print("perimeter: ",cir.get_perimeter())
print("coordinates: ",cir.get_coordinates())
# Out:
# area:  78.53981633974483
# perimeter:  31.41592653589793
# coordinates:  (2, 4)

# %% [markdown]
# 6. Implement an analogous triangle class.

# %%
class triangle(shapes):
    def __init__(self, x1, y1, x2, y2, x3, y3, init_parent=True):
        if init_parent:
            super(triangle,self).__init__(x1, y1)
        self.__coor1=(x1,y1)
        self.__coor2=(x2,y2)
        self.__coor3=(x3,y3)
        self.__a=None
        self.__p=None    

    def is_triangle(self):
        self.__one = math.dist(self.__coor1, self.__coor2)
        self.__two = math.dist(self.__coor2, self.__coor3)
        self.__three = math.dist(self.__coor3, self.__coor1)

        if (self.__one+self.__two>self.__three) and (self.__one+self.__three>self.__two) and (self.__two+self.__three>self.__one):
            return True
        else:
            print("not a triangle")
            return False
    
    def area(self):
        if self.is_triangle()==True:
            s=0.5*(self.__one+self.__two+self.__three)
            self.__a=(s*(s-self.__one)*(s-self.__two)*(s-self.__three))**0.5

    def perimeter(self):
        if self.is_triangle()==True:
            self.__p=self.__one+self.__two+self.__three

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

# %%
tri_F=triangle(0,0,0,2,0,8)
tri_T=triangle(0,0,4,0,1,4)

tri_F.is_triangle()
tri_F.area()
tri_F.perimeter()
print("area: ",tri_F.get_area())
print("perimeter: ",tri_F.get_perimeter())
print("coordinates: ",tri_F.get_coordinates())

tri_T.is_triangle()
tri_T.area()
tri_T.perimeter()
print("\narea: ",tri_T.get_area())
print("perimeter: ",tri_T.get_perimeter())
print("coordinates: ",tri_T.get_coordinates())
# Out:
# not a triangle
# not a triangle
# not a triangle
# area:  None
# perimeter:  None
# coordinates:  (0, 0)
#
# area:  8.000000000000004
# perimeter:  13.123105625617661
# coordinates:  (0, 0)

# %% [markdown]
# 7. Add a function to the object classes that tests if a given set of $x$ and $y$ coordinates are inside of the object.

# %%
class shapes:
    def __init__(self, x, y):
        self.__coor=(x,y)   

    def get_coordinates(self):
        return self.__coor

class rectangle(shapes):
    def __init__(self, length, width, x, y, init_parent=True):
        if init_parent:
            super(rectangle,self).__init__(x, y)
        self.__l=length
        self.__w=width

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(2*self.__l)+(2*self.__w)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is in the bottom left corner of the rectangle
        if (self.get_coordinates()[0] <= check_x <= self.get_coordinates()[0]+self.__w) and \
            (self.get_coordinates()[1] <= check_y <= self.get_coordinates()[1]+self.__l):
            return True
        else:
            return False
        
class circle(shapes):
    def __init__(self, radius, x, y, init_parent=True):
        if init_parent:
            super(circle,self).__init__(x, y)
        self.__r=radius
        self.__i=None
        self.__j=None

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is at the center of the circle
        dist_=(((check_x-self.get_coordinates()[0])**2)+((check_y-self.get_coordinates()[1])**2))**0.5
        if dist_<=self.__r:
            return True
        else:
            return False

class triangle(shapes):
    def __init__(self, x1, y1, x2, y2, x3, y3, init_parent=True):
        if init_parent:
            super(triangle,self).__init__(x1, y1)
        self.__coor1=(x1,y1)
        self.__coor2=(x2,y2)
        self.__coor3=(x3,y3)
        self.__a=None
        self.__p=None    

    def is_triangle(self):
        self.__one = math.dist(self.__coor1, self.__coor2)
        self.__two = math.dist(self.__coor2, self.__coor3)
        self.__three = math.dist(self.__coor3, self.__coor1)

        if (self.__one+self.__two>self.__three) and (self.__one+self.__three>self.__two) and (self.__two+self.__three>self.__one):
            return True
        else:
            print("not a triangle")
            return False
    
    def area(self):
        if self.is_triangle()==True:
            s=0.5*(self.__one+self.__two+self.__three)
            self.__a=(s*(s-self.__one)*(s-self.__two)*(s-self.__three))**0.5

    def perimeter(self):
        if self.is_triangle()==True:
            self.__p=self.__one+self.__two+self.__three

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinates are at each corner
        d=((self.__coor2[1] - self.__coor3[1]) * \
           (self.__coor1[0] - self.__coor3[0]) + (self.__coor3[0] - self.__coor2[0]) * \
           (self.__coor1[1] - self.__coor3[1]))
        
        if d==0:
            return False

        u = ((self.__coor2[1] - self.__coor3[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor3[0] - self.__coor2[0]) * (check_y - self.__coor3[1])) / d
        v = ((self.__coor3[1] - self.__coor1[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor1[0] - self.__coor3[0]) * (check_y - self.__coor3[1])) / d
        w = 1 - u - v

        if 0 <= u <= 1 and 0 <= v <= 1 and 0 <= w <= 1:
            return True
        else:
            return False

# %%
tri=triangle(0,0,0,3,5,0)

tri.check_coordinate(6,6) #False
tri.check_coordinate(1,1) #True
# Out:
# True

# %%
rec=rectangle(4,5,0,0)

rec.check_coordinate(5,5) #False
rec.check_coordinate(2,2) #True
# Out:
# True

# %%
cir=circle(5,0,0)

cir.check_coordinate(5,5) #False
cir.check_coordinate(0,-1) #True
# Out:
# True

# %% [markdown]
# 8. Add a function to the object classes that return a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class shapes:
    def __init__(self, x, y):
        self.__coor=(x,y)   

    def get_coordinates(self):
        return self.__coor

class rectangle(shapes):
    def __init__(self, length, width, x, y, init_parent=True):
        if init_parent:
            super(rectangle,self).__init__(x, y)
        self.__l=length
        self.__w=width

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(2*self.__l)+(2*self.__w)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is in the bottom left corner of the rectangle
        if (self.get_coordinates()[0] <= check_x <= self.get_coordinates()[0]+self.__w) and \
            (self.get_coordinates()[1] <= check_y <= self.get_coordinates()[1]+self.__l):
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1])) #bottom left
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1])) #bottom right
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1] + self.__l)) #top left        
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1] + self.__l)) #top right

        for i in range(1,4):
            top = self.get_coordinates()[0] + (self.__w * i / 4)
            p_points.append((top, self.get_coordinates()[1] + self.__l))

        for i in range(1, 4):
            right = self.get_coordinates()[1] + (self.__l * i / 4)
            p_points.append((self.get_coordinates()[0] + self.__w, right))

        for i in range(1, 4):
            bottom = self.get_coordinates()[0] + (self.__w * (4 - i) / 4)
            p_points.append((bottom, self.get_coordinates()[1]))

        for i in range(1, 4):
            left = self.get_coordinates()[1] + (self.__l * (4 - i) / 4)
            p_points.append((self.get_coordinates()[0], left))

        return p_points
        
class circle(shapes):
    def __init__(self, radius, x, y, init_parent=True):
        if init_parent:
            super(circle,self).__init__(x, y)
        self.__r=radius
        self.__i=None
        self.__j=None

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is at the center of the circle
        dist_=(((check_x-self.get_coordinates()[0])**2)+((check_y-self.get_coordinates()[1])**2))**0.5
        if dist_<=self.__r:
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]  
        for i in range(point):
            a=2*math.pi*i/point
            x=self.__r*math.cos(a)
            y=self.__r*math.sin(a)
            p_points.append((x,y))

        return p_points

class triangle(shapes):
    def __init__(self, x1, y1, x2, y2, x3, y3, init_parent=True):
        if init_parent:
            super(triangle,self).__init__(x1, y1)
        self.__coor1=(x1,y1)
        self.__coor2=(x2,y2)
        self.__coor3=(x3,y3)
        self.__a=None
        self.__p=None    

    def is_triangle(self):
        self.__one = math.dist(self.__coor1, self.__coor2)
        self.__two = math.dist(self.__coor2, self.__coor3)
        self.__three = math.dist(self.__coor3, self.__coor1)

        if (self.__one+self.__two>self.__three) and (self.__one+self.__three>self.__two) and (self.__two+self.__three>self.__one):
            return True
        else:
            print("not a triangle")
            return False
    
    def area(self):
        if self.is_triangle()==True:
            s=0.5*(self.__one+self.__two+self.__three)
            self.__a=(s*(s-self.__one)*(s-self.__two)*(s-self.__three))**0.5

    def perimeter(self):
        if self.is_triangle()==True:
            self.__p=self.__one+self.__two+self.__three

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinates are at each corner
        d=((self.__coor2[1] - self.__coor3[1]) * \
           (self.__coor1[0] - self.__coor3[0]) + (self.__coor3[0] - self.__coor2[0]) * \
           (self.__coor1[1] - self.__coor3[1]))
        
        if d==0:
            return False

        u = ((self.__coor2[1] - self.__coor3[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor3[0] - self.__coor2[0]) * (check_y - self.__coor3[1])) / d
        v = ((self.__coor3[1] - self.__coor1[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor1[0] - self.__coor3[0]) * (check_y - self.__coor3[1])) / d
        w = 1 - u - v

        if 0 <= u <= 1 and 0 <= v <= 1 and 0 <= w <= 1:
            return True
        else:
            return False

    def perimeter_points(self, points=16):
        p_points = []
        p_points.append(self.__coor1)
        p_points.append(self.__coor2)
        p_points.append(self.__coor3)


        for i in range(1, 5):
            x = self.__coor1[0] + (i / 5) * (self.__coor2[0] - self.__coor1[0])
            y = self.__coor1[1] + (i / 5) * (self.__coor2[1] - self.__coor1[1])
            p_points.append((x, y))
        for i in range(1, 5):
            x = self.__coor2[0] + (i / 5) * (self.__coor3[0] - self.__coor2[0])
            y = self.__coor2[1] + (i / 5) * (self.__coor3[1] - self.__coor2[1])
            p_points.append((x, y))
        for i in range(1, 6):
            x = self.__coor3[0] + (i / 6) * (self.__coor1[0] - self.__coor3[0])
            y = self.__coor3[1] + (i / 6) * (self.__coor1[1] - self.__coor3[1])
            p_points.append((x, y))

        return p_points

# %%
rec=rectangle(4,5,0,0)

rec.perimeter_points()
# Out:
# [(0, 0),
#  (5, 0),
#  (0, 4),
#  (5, 4),
#  (1.25, 4),
#  (2.5, 4),
#  (3.75, 4),
#  (5, 1.0),
#  (5, 2.0),
#  (5, 3.0),
#  (3.75, 0),
#  (2.5, 0),
#  (1.25, 0),
#  (0, 3.0),
#  (0, 2.0),
#  (0, 1.0)]

# %%
cir=circle(5,0,0)

cir.perimeter_points()
# Out:
# [(5.0, 0.0),
#  (4.619397662556434, 1.913417161825449),
#  (3.5355339059327378, 3.5355339059327373),
#  (1.9134171618254492, 4.619397662556434),
#  (3.061616997868383e-16, 5.0),
#  (-1.9134171618254485, 4.619397662556434),
#  (-3.5355339059327373, 3.5355339059327378),
#  (-4.619397662556434, 1.9134171618254494),
#  (-5.0, 6.123233995736766e-16),
#  (-4.619397662556434, -1.9134171618254483),
#  (-3.5355339059327386, -3.5355339059327373),
#  (-1.9134171618254516, -4.619397662556432),
#  (-9.184850993605148e-16, -5.0),
#  (1.91341716182545, -4.619397662556433),
#  (3.535533905932737, -3.5355339059327386),
#  (4.619397662556432, -1.913417161825452)]

# %%
tri=triangle(0,0,0,3,5,0)

tri.perimeter_points()
# Out:
# [(0, 0),
#  (0, 3),
#  (5, 0),
#  (0.0, 0.2),
#  (0.0, 0.4),
#  (0.0, 0.6000000000000001),
#  (0.0, 0.8),
#  (0.3333333333333333, 2.8),
#  (0.6666666666666666, 2.6),
#  (1.0, 2.4),
#  (1.3333333333333333, 2.2),
#  (4.666666666666667, 0.0),
#  (4.333333333333333, 0.0),
#  (4.0, 0.0),
#  (3.666666666666667, 0.0),
#  (3.3333333333333335, 0.0)]

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class shapes:
    def __init__(self, x, y):
        self.__coor=(x,y)   

    def get_coordinates(self):
        return self.__coor

    def get_points(self):
        raise NotImplementedError
        
    def check_coordinate(self):
        raise NotImplementedError
    
    def is_overlap(self, other):        
        my_points = self.get_points()
        other_points = other.get_points()

        for p in other_points:
            if self.check_coordinate(p[0], p[1]):
                return True

        for p in my_points:
            if other.check_coordinate(p[0], p[1]):
                return True
            else:
                return False

class rectangle(shapes):
    def __init__(self, length, width, x, y, init_parent=True):
        if init_parent:
            super(rectangle,self).__init__(x, y)
        self.__l=length
        self.__w=width

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(2*self.__l)+(2*self.__w)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is in the bottom left corner of the rectangle
        if (self.get_coordinates()[0] <= check_x <= self.get_coordinates()[0]+self.__w) and \
            (self.get_coordinates()[1] <= check_y <= self.get_coordinates()[1]+self.__l):
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1])) #bottom left
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1])) #bottom right
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1] + self.__l)) #top left        
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1] + self.__l)) #top right

        for i in range(1,4):
            top = self.get_coordinates()[0] + (self.__w * i / 4)
            p_points.append((top, self.get_coordinates()[1] + self.__l))

        for i in range(1, 4):
            right = self.get_coordinates()[1] + (self.__l * i / 4)
            p_points.append((self.get_coordinates()[0] + self.__w, right))

        for i in range(1, 4):
            bottom = self.get_coordinates()[0] + (self.__w * (4 - i) / 4)
            p_points.append((bottom, self.get_coordinates()[1]))

        for i in range(1, 4):
            left = self.get_coordinates()[1] + (self.__l * (4 - i) / 4)
            p_points.append((self.get_coordinates()[0], left))

        return p_points
        
class circle(shapes):
    def __init__(self, radius, x, y, init_parent=True):
        if init_parent:
            super(circle,self).__init__(x, y)
        self.__r=radius
        self.__i=None
        self.__j=None

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is at the center of the circle
        dist_=(((check_x-self.get_coordinates()[0])**2)+((check_y-self.get_coordinates()[1])**2))**0.5
        if dist_<=self.__r:
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]  
        for i in range(point):
            a=2*math.pi*i/point
            x=self.__r*math.cos(a)
            y=self.__r*math.sin(a)
            p_points.append((x,y))

        return p_points

class triangle(shapes):
    def __init__(self, x1, y1, x2, y2, x3, y3, init_parent=True):
        if init_parent:
            super(triangle,self).__init__(x1, y1)
        self.__coor1=(x1,y1)
        self.__coor2=(x2,y2)
        self.__coor3=(x3,y3)
        self.__a=None
        self.__p=None    

    def is_triangle(self):
        self.__one = math.dist(self.__coor1, self.__coor2)
        self.__two = math.dist(self.__coor2, self.__coor3)
        self.__three = math.dist(self.__coor3, self.__coor1)

        if (self.__one+self.__two>self.__three) and (self.__one+self.__three>self.__two) and (self.__two+self.__three>self.__one):
            return True
        else:
            print("not a triangle")
            return False
    
    def area(self):
        if self.is_triangle()==True:
            s=0.5*(self.__one+self.__two+self.__three)
            self.__a=(s*(s-self.__one)*(s-self.__two)*(s-self.__three))**0.5

    def perimeter(self):
        if self.is_triangle()==True:
            self.__p=self.__one+self.__two+self.__three

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinates are at each corner
        d=((self.__coor2[1] - self.__coor3[1]) * \
           (self.__coor1[0] - self.__coor3[0]) + (self.__coor3[0] - self.__coor2[0]) * \
           (self.__coor1[1] - self.__coor3[1]))
        
        if d==0:
            return False

        u = ((self.__coor2[1] - self.__coor3[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor3[0] - self.__coor2[0]) * (check_y - self.__coor3[1])) / d
        v = ((self.__coor3[1] - self.__coor1[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor1[0] - self.__coor3[0]) * (check_y - self.__coor3[1])) / d
        w = 1 - u - v

        if 0 <= u <= 1 and 0 <= v <= 1 and 0 <= w <= 1:
            return True
        else:
            return False

    def perimeter_points(self, points=16):
        p_points = []
        p_points.append(self.__coor1)
        p_points.append(self.__coor2)
        p_points.append(self.__coor3)


        for i in range(1, 5):
            x = self.__coor1[0] + (i / 5) * (self.__coor2[0] - self.__coor1[0])
            y = self.__coor1[1] + (i / 5) * (self.__coor2[1] - self.__coor1[1])
            p_points.append((x, y))
        for i in range(1, 5):
            x = self.__coor2[0] + (i / 5) * (self.__coor3[0] - self.__coor2[0])
            y = self.__coor2[1] + (i / 5) * (self.__coor3[1] - self.__coor2[1])
            p_points.append((x, y))
        for i in range(1, 6):
            x = self.__coor3[0] + (i / 6) * (self.__coor1[0] - self.__coor3[0])
            y = self.__coor3[1] + (i / 6) * (self.__coor1[1] - self.__coor3[1])
            p_points.append((x, y))

        return p_points

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
class shapes:
    def __init__(self, x, y):
        self.__coor=(x,y)   

    def get_coordinates(self):
        return self.__coor

    def get_points(self):
        raise NotImplementedError
        
    def check_coordinate(self):
        raise NotImplementedError
    
    def is_overlap(self, other):        
        my_points = self.get_points()
        other_points = other.get_points()

        for p in other_points:
            if self.check_coordinate(p[0], p[1]):
                return True

        for p in my_points:
            if other.check_coordinate(p[0], p[1]):
                return True
            else:
                return False

    def paint(self, canvas): 
        pass

class rectangle(shapes):
    def __init__(self, length, width, x, y, init_parent=True):
        if init_parent:
            super(rectangle,self).__init__(x, y)
        self.__l=length
        self.__w=width

    def area(self):
        self.__a=self.__l*self.__w

    def perimeter(self):
        self.__p=(2*self.__l)+(2*self.__w)

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is in the bottom left corner of the rectangle
        if (self.get_coordinates()[0] <= check_x <= self.get_coordinates()[0]+self.__w) and \
            (self.get_coordinates()[1] <= check_y <= self.get_coordinates()[1]+self.__l):
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1])) #bottom left
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1])) #bottom right
        p_points.append((self.get_coordinates()[0], self.get_coordinates()[1] + self.__l)) #top left        
        p_points.append((self.get_coordinates()[0] + self.__w, self.get_coordinates()[1] + self.__l)) #top right

        for i in range(1,4):
            top = self.get_coordinates()[0] + (self.__w * i / 4)
            p_points.append((top, self.get_coordinates()[1] + self.__l))

        for i in range(1, 4):
            right = self.get_coordinates()[1] + (self.__l * i / 4)
            p_points.append((self.get_coordinates()[0] + self.__w, right))

        for i in range(1, 4):
            bottom = self.get_coordinates()[0] + (self.__w * (4 - i) / 4)
            p_points.append((bottom, self.get_coordinates()[1]))

        for i in range(1, 4):
            left = self.get_coordinates()[1] + (self.__l * (4 - i) / 4)
            p_points.append((self.get_coordinates()[0], left))

        return p_points

    def paint(self, canvas):
        points = self.perimeter_points()
        for x, y in points:
            canvas.set_pixel(int(x), int(y))
        
class circle(shapes):
    def __init__(self, radius, x, y, init_parent=True):
        if init_parent:
            super(circle,self).__init__(x, y)
        self.__r=radius
        self.__i=None
        self.__j=None

    def area(self):
        self.__a=math.pi*self.__r**2

    def perimeter(self):
        self.__p=2*math.pi*self.__r

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinate is at the center of the circle
        dist_=(((check_x-self.get_coordinates()[0])**2)+((check_y-self.get_coordinates()[1])**2))**0.5
        if dist_<=self.__r:
            return True
        else:
            return False

    def perimeter_points(self, point=16):
        p_points=[]  
        for i in range(point):
            a=2*math.pi*i/point
            x=self.get_coordinates()[0] + self.__r*math.cos(a)
            y=self.get_coordinates()[1] + self.__r*math.sin(a)
            p_points.append((x,y))

        return p_points

    def paint(self, canvas):
        points = self.perimeter_points()
        for x, y in points:
            canvas.set_pixel(int(x), int(y))

class triangle(shapes):
    def __init__(self, x1, y1, x2, y2, x3, y3, init_parent=True):
        if init_parent:
            super(triangle,self).__init__(x1, y1)
        self.__coor1=(x1,y1)
        self.__coor2=(x2,y2)
        self.__coor3=(x3,y3)
        self.__a=None
        self.__p=None    

    def is_triangle(self):
        self.__one = math.dist(self.__coor1, self.__coor2)
        self.__two = math.dist(self.__coor2, self.__coor3)
        self.__three = math.dist(self.__coor3, self.__coor1)

        if (self.__one+self.__two>self.__three) and (self.__one+self.__three>self.__two) and (self.__two+self.__three>self.__one):
            return True
        else:
            print("not a triangle")
            return False
    
    def area(self):
        if self.is_triangle()==True:
            s=0.5*(self.__one+self.__two+self.__three)
            self.__a=(s*(s-self.__one)*(s-self.__two)*(s-self.__three))**0.5

    def perimeter(self):
        if self.is_triangle()==True:
            self.__p=self.__one+self.__two+self.__three

    def get_area(self):
        return self.__a

    def get_perimeter(self):
        return self.__p

    def check_coordinate(self, check_x=None, check_y=None): # coordinates are at each corner
        d=((self.__coor2[1] - self.__coor3[1]) * \
           (self.__coor1[0] - self.__coor3[0]) + (self.__coor3[0] - self.__coor2[0]) * \
           (self.__coor1[1] - self.__coor3[1]))
        
        if d==0:
            return False

        u = ((self.__coor2[1] - self.__coor3[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor3[0] - self.__coor2[0]) * (check_y - self.__coor3[1])) / d
        v = ((self.__coor3[1] - self.__coor1[1]) * (check_x - self.__coor3[0]) + \
             (self.__coor1[0] - self.__coor3[0]) * (check_y - self.__coor3[1])) / d
        w = 1 - u - v

        if 0 <= u <= 1 and 0 <= v <= 1 and 0 <= w <= 1:
            return True
        else:
            return False

    def perimeter_points(self, points=16):
        p_points = []
        p_points.append(self.__coor1)
        p_points.append(self.__coor2)
        p_points.append(self.__coor3)


        for i in range(1, 5):
            x = self.__coor1[0] + (i / 5) * (self.__coor2[0] - self.__coor1[0])
            y = self.__coor1[1] + (i / 5) * (self.__coor2[1] - self.__coor1[1])
            p_points.append((x, y))
        for i in range(1, 5):
            x = self.__coor2[0] + (i / 5) * (self.__coor3[0] - self.__coor2[0])
            y = self.__coor2[1] + (i / 5) * (self.__coor3[1] - self.__coor2[1])
            p_points.append((x, y))
        for i in range(1, 6):
            x = self.__coor3[0] + (i / 6) * (self.__coor1[0] - self.__coor3[0])
            y = self.__coor3[1] + (i / 6) * (self.__coor1[1] - self.__coor3[1])
            p_points.append((x, y))

        return p_points

    def paint(self, canvas):
        points = self.perimeter_points()
        for x, y in points:
            canvas.set_pixel(int(x), int(y))

# %%
from paint import Canvas
from paint import shapes

# %%
class CompoundShape(shapes):
    def __init__(self, *shapes):
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

# %%
c1 = Canvas(40,40)

rec=rectangle(5,5,10,10)
tri=triangle(1,1,10,1,1,15)
cir=circle(4,30,30)

cs=CompoundShape(rec,tri,cir)

#tri.paint(c1)
#rec.paint(c1)
#cir.paint(c1)
cs.paint(c1)

c1.v_line(1,30,4,char='|')

c1.display()
# Out:
#
#  * * *  * * *  *              |
#  *          *                 |
#                               |
#  *       *                    |
#
#  *    *
#
#  * *
#
#  *        **** *
#           *    *
#           *    *
#           *    *
#
#           **** *
#
#
#
#
#
#
#
#
#
#
#                             * **
#                            *    *
#                           *      *
#
#                           *       *
#                           *      *
#                            *    *
#                             *  *
#                               *

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.__width=width
        self.__height=height
        self.__canvas=Canvas(width,height)
        self.__shapes=[]

    def add_shape(self, shape):
        self.__shapes.append(shape)

    def paint(self):
        for shape in self.__shapes:
            shape.paint(self.__canvas)

    def display(self):
        self.__canvas.display()

# %%
drawing=RasterDrawing(60,40)

rec=rectangle(5,9,10,25)
tri=triangle(1,1,10,1,1,15)
cir=circle(5,25,25)

drawing.add_shape(cir)
drawing.add_shape(tri)
drawing.add_shape(rec)

drawing.paint()
drawing.display()
# Out:
#
#  * * *  * * *  *
#  *          *
#
#  *       *
#
#  *    *
#
#  * *
#
#  *                       **** *
#
#                          *    *
#
#                          *    *
#
#                          *    *
#
#
#                          **** *
#                        * **
#                      *      *
#
#                     *        *
#
#                     *         *
#                     *        *
#
#                      *      *
#                        *  *
#                          *

# %%
rec2=rectangle(5,15,20,50)
drawing.add_shape(rec2)

drawing.paint()
drawing.display()
# Out:
#
#  * * *  * * *  *
#  *          *
#
#  *       *
#
#  *    *
#
#  * *
#
#  *                       **** *
#
#                          *    *
#
#                          *    *
#
#                          *    *
#
#
#                          **** *
#                        * **                       **** *
#                      *      *
#
#                     *        *                    *    *
#
#                     *         *
#                     *        *
#                                                   *    *
#                      *      *
#                        *  *
#                          *
#                                                   *    *
#
#
#
#                                                   **** *

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.__width=width
        self.__height=height
        self.__canvas=Canvas(width,height)
        self.__shapes=[]

    def add_shape(self, shape):
        self.__shapes.append(shape)

    def paint(self):
        for shape in self.__shapes:
            shape.paint(self.__canvas)

    def display(self):
        self.__canvas.display()

    def __repr__(self):
        #"foo("+repr(self.a)+","+repr(self.b)+")"
        return "RasterDrawing("+repr(self.__width)+","+repr(self.__height)+")"

    def save(self, filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()

def rast_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# create drawing
my_rast=RasterDrawing(60,60)

rec=rectangle(5,9,10,25)
tri=triangle(1,1,10,1,1,15)
cir=circle(5,25,25)

my_rast.add_shape(cir)
my_rast.add_shape(tri)
my_rast.add_shape(rec)

my_rast.paint()
my_rast.display()

# save drawing
my_rast.save("test.txt")

# load drawing
print(rast_loader("test.txt"))
# Out:
#
#  * * *  * * *  *
#  *          *
#
#  *       *
#
#  *    *
#
#  * *
#
#  *                       **** *
#
#                          *    *
#
#                          *    *
#
#                          *    *
#
#
#                          **** *
#                        * **
#                      *      *
#
#                     *        *
#
#                     *         *
#                     *        *
#
#                      *      *
#                        *  *
#                          *
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# RasterDrawing(60,60)
